# %% [markdown]
# # NY CitiBike Analysis: Rides vs Weather Plots

# %% [markdown]
# ## Import Libraries and Load Data

# %%
# Import libraries
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
from datetime import datetime as dt
import matplotlib

# %%
# Load data
df = pd.read_csv('new_york_data.csv', index_col = 0)
# Out:
# /var/folders/4n/51fny6wj15lbcvykgf0dns700000gn/T/ipykernel_2043/2460435638.py:2: DtypeWarning: Columns (6,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('new_york_data.csv', index_col = 0)

# %%
df.shape
# Out:
# (30689921, 15)

# %%
df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  DF208007EE5F9D79   classic_bike  2022-08-26 15:21:44  2022-08-26 15:34:20
# 1  48A796B4996BACB0  electric_bike  2022-08-03 12:56:29  2022-08-03 13:06:10
# 2  AE459F435C0B1D5B   classic_bike  2022-08-11 17:49:47  2022-08-11 18:05:08
# 3  CA8B4A94620E74C0  electric_bike  2022-08-10 17:25:41  2022-08-10 17:35:23
# 4  EB85C6F0148BC348   classic_bike  2022-08-31 13:47:12  2022-08-31 14:24:00
#
#            start_station_name start_station_id  \
# 0         Berkeley Pl & 6 Ave          4134.06
# 1               21 St & 4 Ave          3668.04
# 2         48 St & Barnett Ave          6358.05
# 3  7 Ave & Central Park South          6912.01
# 4       Jerome Ave & W 195 St          8653.09
#
#                    end_station_name end_station_id  start_lat  start_lng  \
# 0                Windsor Pl & 8 Ave        3620.02  40.676530 -73.978469
# 1              Degraw St & Smith St        4298.05  40.662584 -73.995554
# 2  Queens Plaza North & Crescent St        6429.01  40.750016 -73.915409
# 3                   8 Ave & W 33 St        6450.12  40.766741 -73.979069
# 4            Sherman Ave & E 166 St        8072.06  40.868858 -73.896500
#
#      end_lat    end_lng member_casual        date  avgTemp
# 0  40.660906 -73.983074        member  2022-08-26     27.4
# 1  40.682915 -73.993182        member  2022-08-03     27.6
# 2  40.751102 -73.940737        member  2022-08-11     26.6
# 3  40.751551 -73.993934        member  2022-08-10     27.2
# 4  40.831305 -73.917448        member  2022-08-31     25.6

# %% [markdown]
# ## Temperatures Plot

# %%
# Check date data type
df.dtypes
# Out:
# ride_id                object
# rideable_type          object
# started_at             object
# ended_at               object
# start_station_name     object
# start_station_id       object
# end_station_name       object
# end_station_id         object
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# member_casual          object
# date                   object
# avgTemp               float64
# dtype: object

# %%
# Change to type datetime
df['date'] = pd.to_datetime(df['date'])

# %%
df.dtypes
# Out:
# ride_id                       object
# rideable_type                 object
# started_at                    object
# ended_at                      object
# start_station_name            object
# start_station_id              object
# end_station_name              object
# end_station_id                object
# start_lat                    float64
# start_lng                    float64
# end_lat                      float64
# end_lng                      float64
# member_casual                 object
# date                  datetime64[ns]
# avgTemp                      float64
# dtype: object

# %%
# Create dataframe where date is the index
df_temp = df.set_index('date')

# %%
df_temp.head()
# Out:
#                      ride_id  rideable_type           started_at  \
# date
# 2022-08-26  DF208007EE5F9D79   classic_bike  2022-08-26 15:21:44
# 2022-08-03  48A796B4996BACB0  electric_bike  2022-08-03 12:56:29
# 2022-08-11  AE459F435C0B1D5B   classic_bike  2022-08-11 17:49:47
# 2022-08-10  CA8B4A94620E74C0  electric_bike  2022-08-10 17:25:41
# 2022-08-31  EB85C6F0148BC348   classic_bike  2022-08-31 13:47:12
#
#                        ended_at          start_station_name start_station_id  \
# date
# 2022-08-26  2022-08-26 15:34:20         Berkeley Pl & 6 Ave          4134.06
# 2022-08-03  2022-08-03 13:06:10               21 St & 4 Ave          3668.04
# 2022-08-11  2022-08-11 18:05:08         48 St & Barnett Ave          6358.05
# 2022-08-10  2022-08-10 17:35:23  7 Ave & Central Park South          6912.01
# 2022-08-31  2022-08-31 14:24:00       Jerome Ave & W 195 St          8653.09
#
#                             end_station_name end_station_id  start_lat  \
# date
# 2022-08-26                Windsor Pl & 8 Ave        3620.02  40.676530
# 2022-08-03              Degraw St & Smith St        4298.05  40.662584
# 2022-08-11  Queens Plaza North & Crescent St        6429.01  40.750016
# 2022-08-10                   8 Ave & W 33 St        6450.12  40.766741
# 2022-08-31            Sherman Ave & E 166 St        8072.06  40.868858
#
#             start_lng    end_lat    end_lng member_casual  avgTemp
# date
# 2022-08-26 -73.978469  40.660906 -73.983074        member     27.4
# 2022-08-03 -73.995554  40.682915 -73.993182        member     27.6
# 2022-08-11 -73.915409  40.751102 -73.940737        member     26.6
# 2022-08-10 -73.979069  40.751551 -73.993934        member     27.2
# 2022-08-31 -73.896500  40.831305 -73.917448        member     25.6

# %%
# Plot temperatures using pandas
plt.figure(figsize = (10,4))
df_temp['avgTemp'].plot()
# Out:
# <Axes: xlabel='date'>

# %% [markdown]
# ## Create bike_rides_daily Column

# %%
# Group by the count of the trips each day
df_group = pd.DataFrame(df.groupby(['date'])['ride_id'].count()).reset_index()

# %%
df_group.head()
# Out:
#         date  ride_id
# 0 2022-01-01    20895
# 1 2022-01-02    44234
# 2 2022-01-03    34126
# 3 2022-01-04    37879
# 4 2022-01-05    35080

# %%
# Rename columns
df_group.rename(columns = {'ride_id':'bike_rides_daily'}, inplace = True)

# %%
# Merge with df
df = df.merge(df_group, on = 'date', how = 'outer', indicator = True)

# %%
# Check
print("Shape of January 1st is", df[df['date'] == '2018-01-01'].shape) # Check 
print("Shape of January 2nd is", df[df['date'] == '2018-01-02'].shape) # Second check
# Out:
# Shape of January 1st is (0, 17)
# Shape of January 2nd is (0, 17)

# %%
# Remove _merge column
df.drop(columns = {'_merge'}, inplace = True)

# %%
# Create dataframe where date is the index
df_temp = df.set_index('date')

# %%
df_temp.head()
# Out:
#                      ride_id  rideable_type           started_at  \
# date
# 2022-01-01  F2147CAB2E003A12   classic_bike  2022-01-01 00:56:36
# 2022-01-01  27FF7FCE0F8A02DF   classic_bike  2022-01-01 15:42:26
# 2022-01-01  E413BC1D0B4C6031   classic_bike  2022-01-01 15:37:55
# 2022-01-01  1967ADD90811CE78  electric_bike  2022-01-01 17:35:23
# 2022-01-01  D199C729356BA836   classic_bike  2022-01-01 19:25:20
#
#                        ended_at        start_station_name start_station_id  \
# date
# 2022-01-01  2022-01-01 01:06:55  Cedar St & Evergreen Ave          4721.01
# 2022-01-01  2022-01-01 16:02:59  Albany St & Greenwich St          5145.02
# 2022-01-01  2022-01-01 16:03:05  Albany St & Greenwich St          5145.02
# 2022-01-01  2022-01-01 17:46:05   Cabrini Blvd & W 177 St           8358.1
# 2022-01-01  2022-01-01 19:41:53           5 Ave & E 72 St          7100.07
#
#                          end_station_name end_station_id  start_lat  \
# date
# 2022-01-01  Willoughby Ave & Tompkins Ave        4665.02  40.696710
# 2022-01-01          Bayard St & Baxter St        5351.03  40.709267
# 2022-01-01          Bayard St & Baxter St        5351.03  40.709267
# 2022-01-01            Broadway & W 220 St        8715.01  40.848282
# 2022-01-01                W 41 St & 8 Ave        6602.03  40.772828
#
#             start_lng    end_lat    end_lng member_casual  avgTemp  \
# date
# 2022-01-01 -73.928070  40.694254 -73.946269        member     11.6
# 2022-01-01 -74.013247  40.716021 -73.999744        casual     11.6
# 2022-01-01 -74.013247  40.716021 -73.999744        casual     11.6
# 2022-01-01 -73.941343  40.872412 -73.912807        member     11.6
# 2022-01-01 -73.966853  40.756405 -73.990026        casual     11.6
#
#             bike_rides_daily
# date
# 2022-01-01             20895
# 2022-01-01             20895
# 2022-01-01             20895
# 2022-01-01             20895
# 2022-01-01             20895

# %% [markdown]
# ## Temperatures and Bike Rides Plot

# %%
# Create figure and axis objects with subplots() and details
fig,ax = plt.subplots(figsize = (10, 5))

# Make a plot of the bike rides
ax.plot(df_temp['bike_rides_daily'], color = 'navy')
ax.set_xlabel('Year 2022', fontsize = 14) # set x-axis label
ax.set_ylabel('Bike Rides Daily', color = 'navy', fontsize = 14) # set y-axis label

# Create the dual axis - initialize a twin object for two different y-axis on the sample plot
ax2 = ax.twinx()

# Make a plot of the temperatues on the y-axis using second axis object
ax2.plot(df_temp["avgTemp"], color = 'red')
ax2.set_ylabel('Average Temperatures', color = 'red', fontsize = 14)

plt.title('Temperature and Bike Rides in New York 2022', fontsize = 18)
plt.show()

# %% [markdown]
# #### In the above graph I used matplotlib in an object oriented manner to plot the number of daily bike rides and average temperatures on the same figure. First I created figure and axis objects using subplot(). Then I plotted the bike rides using object ax. Next I created the dual axis (ax2) using twinx() and plotted the temperatures using object ax2. Lastly I added a title to the whole graph.
